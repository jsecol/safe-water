# %%
import os
import pandas as pd

# pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', 50)

# %%
ECHODATA_PATH = '../data/echo_exporter_sdwis.csv.gz'

ECHOdata_sdwis = pd.read_csv(ECHODATA_PATH, compression='gzip', header=0, sep=',', 
                        dtype={0:'str'}, quotechar='"', low_memory=False, index_col=False) #, nrows=5

ECHOdata_sdwis.shape
# Out:
# (420290, 135)

# %%
ECHOdata_sdwis.head(10)
# Out:
#   Unnamed: 0   REGISTRY_ID                                  FAC_NAME  \
# 0         61  1.100099e+11                      MDC-CAMP CUSINO WWSL
# 1        121  1.100130e+11                TEL COMPANY 3 WATER SYSTEM
# 2        122  1.100006e+11   BLACK HILLS CORP - NEIL SIMPSON COMPLEX
# 3        125  1.100082e+11         LEWIS RIVER STATE SALMON HATCHERY
# 4        135  1.100168e+11  SEVERANCE PHASE I MUNICIPAL WATER SYSTEM
# 5        137  1.100172e+11                           NICHOLS TOWN OF
# 6        141  1.100133e+11                       BREEZY POINT CONDOS
# 7        143  1.100176e+11                          LAWSON'S LANDING
# 8        145  1.100191e+11                   HALE CREEK ASACT CENTER
# 9        148  1.100202e+11                            CLIVE, CITY OF
#
#                        FAC_STREET      FAC_CITY FAC_STATE FAC_ZIP FAC_COUNTY  \
# 0                CAMP CUSINO WWSL    SHINGLETON        MI   49884      ALGER
# ...

# %%
pd.set_option('display.max_colwidth', -1)

# %%
ECHOdata_sdwis.loc[1:50, 'DFR_URL']
# Out:
# 1     http://echo.epa.gov/detailed-facility-report?fid=110012988838
# 2     http://echo.epa.gov/detailed-facility-report?fid=110000600341
# 3     http://echo.epa.gov/detailed-facility-report?fid=110008221165
# 4     http://echo.epa.gov/detailed-facility-report?fid=110016803020
# 5     http://echo.epa.gov/detailed-facility-report?fid=110017182911
# 6     http://echo.epa.gov/detailed-facility-report?fid=110013252103
# 7     http://echo.epa.gov/detailed-facility-report?fid=110017628744
# 8     http://echo.epa.gov/detailed-facility-report?fid=110019078282
# 9     http://echo.epa.gov/detailed-facility-report?fid=110020160476
# 10    http://echo.epa.gov/detailed-facility-report?fid=110047936506
# 11    http://echo.epa.gov/detailed-facility-report?fid=110048384789
# 12    http://echo.epa.gov/detailed-facility-report?fid=110049767908
# 13    http://echo.epa.gov/detailed-facility-report?fid=110049554656
# 14    http://echo.epa.gov/detailed-facility-report?fid=110049025381
# ...

# %% [markdown]
# dang, little help it seems:
# https://iaspub.epa.gov/enviro/efservice/WATER_SYSTEM_FACILITY/ROWS/0:10
